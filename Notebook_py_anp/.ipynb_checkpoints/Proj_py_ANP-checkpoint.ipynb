# %%
from jupyterthemes import jtplot
jtplot.style(theme = 'monokai')
import pandas as pd

# %%
df = pd.read_csv("2023_01_producao_Presal.csv", sep = ";")
df
# Out:
#              Estado   Bacia        Nome Poço   Unnamed: 3      Campo  \
# 0               NaN     NaN              ANP     Operador        NaN
# 1               NaN     NaN              NaN          NaN        NaN
# 2    Rio de Janeiro  Santos  1-BRSA-1116-RJS      1RJS704  ITAPU_ECO
# 3    Rio de Janeiro  Santos      7-LL-46-RJS     7LL46RJS       TUPI
# 4    Rio de Janeiro  Santos     7-LL-45D-RJS    7LL45DRJS       TUPI
# ..              ...     ...              ...          ...        ...
# 343  Rio de Janeiro  Santos    7-BUZ-31D-RJS   7BUZ31DRJS     BÚZIOS
# 344  Rio de Janeiro  Santos     7-BUZ-30-RJS    7BUZ30RJS     BÚZIOS
# 345  Rio de Janeiro  Santos    7-BUZ-29D-RJS   7BUZ29DRJS     BÚZIOS
# 346  Rio de Janeiro  Santos   7-BUZ-36DA-RJS  7BUZ36DARJS     BÚZIOS
# 347  Rio de Janeiro  Santos    7-BUZ-24D-RJS   7BUZ24DRJS     BÚZIOS
#
#       Operador Número do Contrato  Período Óleo (bbl/dia)  \
# 0          NaN                NaN      NaN            NaN
# 1          NaN                NaN      NaN            NaN
# 2    Petrobras  48610012913201005  2023/01    24.589,0097
# 3    Petrobras    486100038862000  2023/01     9.268,5707
# 4    Petrobras    486100038862000  2023/01     2.229,7516
# ..         ...                ...      ...            ...
# 343  Petrobras  48610012913201005  2023/01    10.217,2163
# 344  Petrobras  48610012913201005  2023/01    10.972,9944
# 345  Petrobras  48610012913201005  2023/01     3.896,5870
# 346  Petrobras  48610012913201005  2023/01     2.954,0391
# 347  Petrobras  48610012913201005  2023/01    11.995,2534
#
#     Condensado (bbl/dia)  ... Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# 0                    NaN  ...     Nonanos     Decanos   Undecanos    Oxigênio
# 1                    NaN  ...         NaN         NaN         NaN         NaN
# 2                 0,0000  ...       0,025       0,016           0           0
# 3                 0,0000  ...         NaN         NaN         NaN         NaN
# 4                 0,0000  ...         NaN         NaN         NaN         NaN
# ..                   ...  ...         ...         ...         ...         ...
# 343               0,0000  ...        0,04        0,01           0         0,2
# 344               0,0000  ...        0,04        0,01           0         0,2
# 345               0,0000  ...        0,04        0,01           0         0,2
# 346               0,0000  ...        0,04        0,01           0         0,2
# 347               0,0000  ...        0,04        0,01           0         0,2
#
#     Unnamed: 42    Unnamed: 43 Densidade GLP Gás Densidade GLP Líquido  \
# 0    Nitrogênio  Gás Carbônico               NaN                   NaN
# 1           NaN            NaN               NaN                   NaN
# 2         0,799          0,101             2,004             528,51919
# 3           NaN            NaN               NaN                   NaN
# 4           NaN            NaN               NaN                   NaN
# ..          ...            ...               ...                   ...
# 343        1,31          11,58           2,04893             533,88699
# 344        1,31          11,58           2,04893             533,88699
# 345        1,31          11,58           2,04893             533,88699
# 346        1,31          11,58           2,04893             533,88699
# 347        1,31          11,58           2,04893             533,88699
#
#      PCS GP\n(kJ/m³) Data de atualização
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2         42662,1051          13/03/2023
# 3                NaN          13/03/2023
# 4                NaN          13/03/2023
# ..               ...                 ...
# 343       35593,3546          13/03/2023
# 344       35593,3546          13/03/2023
# 345       35593,3546          13/03/2023
# 346       35593,3546          13/03/2023
# 347       35593,3546          13/03/2023
#
# [348 rows x 48 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cleaned = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df_cleaned.head()
# Out:
#             Estado   Bacia        Nome Poço        Campo   Operador  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    ITAPU_ECO  Petrobras
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  SUL DE TUPI  Petrobras
# 18  Rio de Janeiro  Santos      7-LL-97-RJS  SUL DE TUPI  Petrobras
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  SUL DE TUPI  Petrobras
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  SUL DE TUPI  Petrobras
#
#    Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  \
# 2   48610012913201005  2023/01    24.589,0097               0,0000
# 17    486100038862000  2023/01     1.581,4644               0,0000
# 18    486100038862000  2023/01       558,4049               0,0000
# 19    486100038862000  2023/01     1.045,6631               0,0000
# 20    486100038862000  2023/01       982,3675               0,0000
#
#    Petróleo (bbl/dia)  ... Tempo de Produção (hs por mês) Período da Carga  \
# 2         24.589,0097  ...                            0.0          2022/12
# 17         1.581,4644  ...                          677.0          2022/02
# 18           558,4049  ...                          685.0          2022/02
# 19         1.045,6631  ...                          685.0          2022/02
# 20           982,3675  ...                          423.0          2022/02
#
#                Corrente Grau API Fração de Destilados  % em Volumes  \
# 2                 ITAPU     29,3              < 270ºC        67,708
# 17  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 18  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 19  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 20  Área de Sul de Tupi     30,2              < 270ºC        71,809
#
#    Densidade GLP Gás Densidade GLP Líquido PCS GP\n(kJ/m³) Data de atualização
# 2              2,004             528,51919      42662,1051          13/03/2023
# 17           2,00144             528,22646      38798,0539          13/03/2023
# 18           2,00144             528,22646      38798,0539          13/03/2023
# 19           2,00144             528,22646      38798,0539          13/03/2023
# 20           2,00144             528,22646      38798,0539          13/03/2023
#
# [5 rows x 25 columns]

# %%
df.isnull()
# Out:
#      Estado  Bacia  Nome Poço  Unnamed: 3  Campo  Operador  \
# 2     False  False      False       False  False     False
# 17    False  False      False       False  False     False
# 18    False  False      False       False  False     False
# 19    False  False      False       False  False     False
# 20    False  False      False       False  False     False
# ..      ...    ...        ...         ...    ...       ...
# 343   False  False      False       False  False     False
# 344   False  False      False       False  False     False
# 345   False  False      False       False  False     False
# 346   False  False      False       False  False     False
# 347   False  False      False       False  False     False
#
#      Número do Contrato  Período  Óleo (bbl/dia)  Condensado (bbl/dia)  ...  \
# 2                 False    False           False                 False  ...
# 17                False    False           False                 False  ...
# 18                False    False           False                 False  ...
# 19                False    False           False                 False  ...
# 20                False    False           False                 False  ...
# ..                  ...      ...             ...                   ...  ...
# 343               False    False           False                 False  ...
# 344               False    False           False                 False  ...
# 345               False    False           False                 False  ...
# 346               False    False           False                 False  ...
# 347               False    False           False                 False  ...
#
#      Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 2          False        False        False        False        False
# 17         False        False        False        False        False
# 18         False        False        False        False        False
# 19         False        False        False        False        False
# 20         False        False        False        False        False
# ..           ...          ...          ...          ...          ...
# 343        False        False        False        False        False
# 344        False        False        False        False        False
# 345        False        False        False        False        False
# 346        False        False        False        False        False
# 347        False        False        False        False        False
#
#      Unnamed: 43  Densidade GLP Gás  Densidade GLP Líquido  PCS GP\n(kJ/m³)  \
# 2          False              False                  False            False
# 17         False              False                  False            False
# 18         False              False                  False            False
# 19         False              False                  False            False
# 20         False              False                  False            False
# ..           ...                ...                    ...              ...
# 343        False              False                  False            False
# 344        False              False                  False            False
# 345        False              False                  False            False
# 346        False              False                  False            False
# 347        False              False                  False            False
#
#      Data de atualização
# 2                  False
# 17                 False
# 18                 False
# 19                 False
# 20                 False
# ..                   ...
# 343                False
# 344                False
# 345                False
# 346                False
# 347                False
#
# [227 rows x 48 columns]

# %%
df_cleaned = df.dropna()
df_cleaned.head()
# Out:
#             Estado   Bacia        Nome Poço Unnamed: 3        Campo  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    1RJS704    ITAPU_ECO
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  7LL105RJS  SUL DE TUPI
# 18  Rio de Janeiro  Santos      7-LL-97-RJS   7LL97RJS  SUL DE TUPI
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  7LL100RJS  SUL DE TUPI
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  7LL115RJS  SUL DE TUPI
#
#      Operador Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  \
# 2   Petrobras  48610012913201005  2023/01    24.589,0097               0,0000
# 17  Petrobras    486100038862000  2023/01     1.581,4644               0,0000
# 18  Petrobras    486100038862000  2023/01       558,4049               0,0000
# 19  Petrobras    486100038862000  2023/01     1.045,6631               0,0000
# 20  Petrobras    486100038862000  2023/01       982,3675               0,0000
#
#     ... Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 2   ...       0,025       0,016           0           0       0,799
# 17  ...       0,015       0,003           0        0,06       0,879
# 18  ...       0,015       0,003           0        0,06       0,879
# 19  ...       0,015       0,003           0        0,06       0,879
# 20  ...       0,015       0,003           0        0,06       0,879
#
#    Unnamed: 43 Densidade GLP Gás Densidade GLP Líquido  PCS GP\n(kJ/m³)  \
# 2        0,101             2,004             528,51919       42662,1051
# 17       5,271           2,00144             528,22646       38798,0539
# 18       5,271           2,00144             528,22646       38798,0539
# 19       5,271           2,00144             528,22646       38798,0539
# 20       5,271           2,00144             528,22646       38798,0539
#
#    Data de atualização
# 2           13/03/2023
# 17          13/03/2023
# 18          13/03/2023
# 19          13/03/2023
# 20          13/03/2023
#
# [5 rows x 48 columns]

# %%
df.dropna(inplace=True)

# %%
df_cleaned.to_csv("2023_01_producao_Presal.csv", index=False)
df_cleaned.head()
# Out:
#             Estado   Bacia        Nome Poço        Campo   Operador  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    ITAPU_ECO  Petrobras
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  SUL DE TUPI  Petrobras
# 18  Rio de Janeiro  Santos      7-LL-97-RJS  SUL DE TUPI  Petrobras
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  SUL DE TUPI  Petrobras
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  SUL DE TUPI  Petrobras
#
#    Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  \
# 2   48610012913201005  2023/01    24.589,0097               0,0000
# 17    486100038862000  2023/01     1.581,4644               0,0000
# 18    486100038862000  2023/01       558,4049               0,0000
# 19    486100038862000  2023/01     1.045,6631               0,0000
# 20    486100038862000  2023/01       982,3675               0,0000
#
#    Petróleo (bbl/dia)  ... Tempo de Produção (hs por mês) Período da Carga  \
# 2         24.589,0097  ...                            0.0          2022/12
# 17         1.581,4644  ...                          677.0          2022/02
# 18           558,4049  ...                          685.0          2022/02
# 19         1.045,6631  ...                          685.0          2022/02
# 20           982,3675  ...                          423.0          2022/02
#
#                Corrente Grau API Fração de Destilados  % em Volumes  \
# 2                 ITAPU     29,3              < 270ºC        67,708
# 17  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 18  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 19  Área de Sul de Tupi     30,2              < 270ºC        71,809
# 20  Área de Sul de Tupi     30,2              < 270ºC        71,809
#
#    Densidade GLP Gás Densidade GLP Líquido PCS GP\n(kJ/m³) Data de atualização
# 2              2,004             528,51919      42662,1051          13/03/2023
# 17           2,00144             528,22646      38798,0539          13/03/2023
# 18           2,00144             528,22646      38798,0539          13/03/2023
# 19           2,00144             528,22646      38798,0539          13/03/2023
# 20           2,00144             528,22646      38798,0539          13/03/2023
#
# [5 rows x 25 columns]

# %%
dados = df_cleaned[df_cleaned.duplicated()]
dados
# Out:
# Empty DataFrame
# Columns: [Estado, Bacia, Nome Poço, Campo, Operador, Número do Contrato, Período, Óleo (bbl/dia), Condensado (bbl/dia), Petróleo (bbl/dia), Gás Natural (Mm³/dia), Volume Gás Royalties (Mm³/dia), Água (bbl/dia), Instalação Destino, Tipo Instalação, Tempo de Produção (hs por mês), Período da Carga, Corrente, Grau API, Fração de Destilados, % em Volumes, Densidade GLP Gás, Densidade GLP Líquido, PCS GP
# (kJ/m³), Data de atualização]
# Index: []
#
# [0 rows x 25 columns]

# %%
numero_duplicados = df_cleaned.duplicated().sum()
print(f"Número de linhas duplicadas: {numero_duplicados}")
# Out:
# Número de linhas duplicadas: 0

# %%
nan_count = df_cleaned.isna().sum()
nan_count
# Out:
# Estado                            0
# Bacia                             0
# Nome Poço                         0
# Campo                             0
# Operador                          0
# Número do Contrato                0
# Período                           0
# Óleo (bbl/dia)                    0
# Condensado (bbl/dia)              0
# Petróleo (bbl/dia)                0
# Gás Natural (Mm³/dia)             0
# Volume Gás Royalties (Mm³/dia)    0
# Água (bbl/dia)                    0
# Instalação Destino                0
# Tipo Instalação                   0
# Tempo de Produção (hs por mês)    0
# Período da Carga                  0
# Corrente                          0
# Grau API                          0
# Fração de Destilados              0
# % em Volumes                      0
# Densidade GLP Gás                 0
# Densidade GLP Líquido             0
# PCS GP\n(kJ/m³)                   0
# Data de atualização               0
# dtype: int64

# %%
df_cleaned.columns
# Out:
# Index(['Estado', 'Bacia', 'Nome Poço', 'Campo', 'Operador',
#        'Número do Contrato', 'Período', 'Óleo (bbl/dia)',
#        'Condensado (bbl/dia)', 'Petróleo (bbl/dia)', 'Gás Natural (Mm³/dia)',
#        'Volume Gás Royalties (Mm³/dia)', 'Água (bbl/dia)',
#        'Instalação Destino', 'Tipo Instalação',
#        'Tempo de Produção (hs por mês)', 'Período da Carga', 'Corrente',
#        'Grau API', 'Fração de Destilados', '% em Volumes', 'Densidade GLP Gás',
#        'Densidade GLP Líquido', 'PCS GP\n(kJ/m³)', 'Data de atualização'],
#       dtype='object')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, 2 to 347
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Estado                          227 non-null    object
#  1   Bacia                           227 non-null    object
#  2   Nome Poço                       227 non-null    object
#  3   Campo                           227 non-null    object
#  4   Operador                        227 non-null    object
#  5   Número do Contrato              227 non-null    object
#  6   Período                         227 non-null    object
#  7   Óleo (bbl/dia)                  227 non-null    object
#  8   Condensado (bbl/dia)            227 non-null    object
#  9   Petróleo (bbl/dia)              227 non-null    object
#  10  Gás Natural (Mm³/dia)           227 non-null    object
#  11  Volume Gás Royalties (Mm³/dia)  227 non-null    object
#  12  Água (bbl/dia)                  227 non-null    object
#  13  Instalação Destino              227 non-null    object
#  14  Tipo Instalação                 227 non-null    object
#  15  Tempo de Produção (hs por mês)  227 non-null    float64
#  16  Período da Carga                227 non-null    object
#  17  Corrente                        227 non-null    object
#  18  Grau API                        227 non-null    object
#  19  Fração de Destilados            227 non-null    object
#  20  % em Volumes                    227 non-null    object
#  21  Densidade GLP Gás               227 non-null    object
#  22  Densidade GLP Líquido           227 non-null    object
#  23  PCS GP
# (kJ/m³)                  227 non-null    object
#  24  Data de atualização             227 non-null    object
# dtypes: float64(1), object(24)
# memory usage: 46.1+ KB

# %%
import pandas as pd

# Lista de colunas numéricas que você quer converter
colunas_numericas = [
    'Óleo (bbl/dia)', 
    'Condensado (bbl/dia)', 
    'Petróleo (bbl/dia)', 
    'Gás Natural (Mm³/dia)', 
    'Volume Gás Royalties (Mm³/dia)', 
    'Água (bbl/dia)', 
    'Grau API',
    'Fração de Destilados',
    '% em Volumes',
    'Densidade GLP Gás',
    'Densidade GLP Líquido',
    'PCS GP\n(kJ/m³)'
]

# Remover pontos e substituir vírgulas por pontos, depois converter para numérico
for coluna in colunas_numericas:
    df[coluna] = df[coluna].str.replace('.', '', regex=False)  # Remove separador de milhares
    df[coluna] = df[coluna].str.replace(',', '.', regex=False)  # Substitui vírgulas por pontos
    df[coluna] = pd.to_numeric(df[coluna], errors='coerce')  # Converte para numérico

# Verifique as primeiras linhas e os tipos de dados
print(df.head())
print(df.dtypes)
# Out:
#             Estado   Bacia        Nome Poço Unnamed: 3        Campo  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    1RJS704    ITAPU_ECO
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  7LL105RJS  SUL DE TUPI
# 18  Rio de Janeiro  Santos      7-LL-97-RJS   7LL97RJS  SUL DE TUPI
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  7LL100RJS  SUL DE TUPI
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  7LL115RJS  SUL DE TUPI
#
#      Operador  Período  Óleo (bbl/dia)  Condensado (bbl/dia)  \
# 2   Petrobras  2023/01      24589.0097                   0.0
# 17  Petrobras  2023/01       1581.4644                   0.0
# 18  Petrobras  2023/01        558.4049                   0.0
# 19  Petrobras  2023/01       1045.6631                   0.0
# 20  Petrobras  2023/01        982.3675                   0.0
#
#     Petróleo (bbl/dia)  ...  Unnamed: 38 Unnamed: 39 Unnamed: 40  Unnamed: 41  \
# 2           24589.0097  ...        0,025       0,016           0            0
# 17           1581.4644  ...        0,015       0,003           0         0,06
# 18            558.4049  ...        0,015       0,003           0         0,06
# 19           1045.6631  ...        0,015       0,003           0         0,06
# 20            982.3675  ...        0,015       0,003           0         0,06
#
#     Unnamed: 42 Unnamed: 43 Densidade GLP Gás  Densidade GLP Líquido  \
# 2         0,799       0,101           2.00400              528.51919
# 17        0,879       5,271           2.00144              528.22646
# 18        0,879       5,271           2.00144              528.22646
# 19        0,879       5,271           2.00144              528.22646
# 20        0,879       5,271           2.00144              528.22646
#
#    PCS GP\n(kJ/m³)  Data de atualização
# 2       42662.1051           13/03/2023
# 17      38798.0539           13/03/2023
# 18      38798.0539           13/03/2023
# 19      38798.0539           13/03/2023
# 20      38798.0539           13/03/2023
#
# [5 rows x 46 columns]
# Estado                             object
# Bacia                              object
# Nome Poço                          object
# Unnamed: 3                         object
# Campo                              object
# Operador                           object
# Período                            object
# Óleo (bbl/dia)                    float64
# Condensado (bbl/dia)              float64
# Petróleo (bbl/dia)                float64
# Gás Natural (Mm³/dia)             float64
# Unnamed: 12                        object
# Unnamed: 13                        object
# Volume Gás Royalties (Mm³/dia)    float64
# Água (bbl/dia)                    float64
# Instalação Destino                 object
# Tipo Instalação                    object
# Tempo de Produção (hs por mês)    float64
# Corrente                           object
# Grau API                          float64
# Fração de Destilados              float64
# Unnamed: 23                        object
# Unnamed: 24                        object
# Unnamed: 25                        object
# Unnamed: 26                        object
# Unnamed: 27                        object
# % em Volumes                      float64
# Unnamed: 29                        object
# Unnamed: 30                        object
# Unnamed: 31                        object
# Unnamed: 32                        object
# Unnamed: 33                        object
# Unnamed: 34                        object
# Unnamed: 35                        object
# Unnamed: 36                        object
# Unnamed: 37                        object
# Unnamed: 38                        object
# Unnamed: 39                        object
# Unnamed: 40                        object
# Unnamed: 41                        object
# Unnamed: 42                        object
# Unnamed: 43                        object
# Densidade GLP Gás                 float64
# Densidade GLP Líquido             float64
# PCS GP\n(kJ/m³)                   float64
# Data de atualização                object
# dtype: object

# %%
colunas_para_remover = [
    'Número do Contrato',
    'Período da Carga',
    ]

# %%
df.columns = df.columns.str.strip()

# %%
df = df.drop(columns=colunas_para_remover, errors='ignore')
df.head()
# Out:
#             Estado   Bacia        Nome Poço Unnamed: 3        Campo  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    1RJS704    ITAPU_ECO
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  7LL105RJS  SUL DE TUPI
# 18  Rio de Janeiro  Santos      7-LL-97-RJS   7LL97RJS  SUL DE TUPI
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  7LL100RJS  SUL DE TUPI
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  7LL115RJS  SUL DE TUPI
#
#      Operador  Período Óleo (bbl/dia) Condensado (bbl/dia) Petróleo (bbl/dia)  \
# 2   Petrobras  2023/01    24.589,0097               0,0000        24.589,0097
# 17  Petrobras  2023/01     1.581,4644               0,0000         1.581,4644
# 18  Petrobras  2023/01       558,4049               0,0000           558,4049
# 19  Petrobras  2023/01     1.045,6631               0,0000         1.045,6631
# 20  Petrobras  2023/01       982,3675               0,0000           982,3675
#
#     ... Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 2   ...       0,025       0,016           0           0       0,799
# 17  ...       0,015       0,003           0        0,06       0,879
# 18  ...       0,015       0,003           0        0,06       0,879
# 19  ...       0,015       0,003           0        0,06       0,879
# 20  ...       0,015       0,003           0        0,06       0,879
#
#    Unnamed: 43 Densidade GLP Gás  Densidade GLP Líquido PCS GP\n(kJ/m³)  \
# 2        0,101             2,004              528,51919      42662,1051
# 17       5,271           2,00144              528,22646      38798,0539
# 18       5,271           2,00144              528,22646      38798,0539
# 19       5,271           2,00144              528,22646      38798,0539
# 20       5,271           2,00144              528,22646      38798,0539
#
#    Data de atualização
# 2           13/03/2023
# 17          13/03/2023
# 18          13/03/2023
# 19          13/03/2023
# 20          13/03/2023
#
# [5 rows x 46 columns]

# %%
dados_limpos = df_cleaned = df_cleaned.dropna()
dados_limpos.head()
# Out:
#             Estado   Bacia        Nome Poço        Campo   Operador  Período  \
# 2   Rio de Janeiro  Santos  1-BRSA-1116-RJS    ITAPU_ECO  Petrobras  2023/01
# 17  Rio de Janeiro  Santos     7-LL-105-RJS  SUL DE TUPI  Petrobras  2023/01
# 18  Rio de Janeiro  Santos      7-LL-97-RJS  SUL DE TUPI  Petrobras  2023/01
# 19  Rio de Janeiro  Santos     7-LL-100-RJS  SUL DE TUPI  Petrobras  2023/01
# 20  Rio de Janeiro  Santos     7-LL-115-RJS  SUL DE TUPI  Petrobras  2023/01
#
#    Óleo (bbl/dia) Condensado (bbl/dia) Petróleo (bbl/dia)  \
# 2     24.589,0097               0,0000        24.589,0097
# 17     1.581,4644               0,0000         1.581,4644
# 18       558,4049               0,0000           558,4049
# 19     1.045,6631               0,0000         1.045,6631
# 20       982,3675               0,0000           982,3675
#
#    Gás Natural (Mm³/dia)  ... Tipo Instalação Tempo de Produção (hs por mês)  \
# 2               288,0496  ...             UEP                            0.0
# 17               58,9039  ...             UEP                          677.0
# 18               28,5560  ...             UEP                          685.0
# 19               45,3490  ...             UEP                          685.0
# 20               36,2552  ...             UEP                          423.0
#
#                Corrente Grau API  Fração de Destilados % em Volumes  \
# 2                 ITAPU     29,3               < 270ºC       67,708
# 17  Área de Sul de Tupi     30,2               < 270ºC       71,809
# 18  Área de Sul de Tupi     30,2               < 270ºC       71,809
# 19  Área de Sul de Tupi     30,2               < 270ºC       71,809
# 20  Área de Sul de Tupi     30,2               < 270ºC       71,809
#
#    Densidade GLP Gás Densidade GLP Líquido PCS GP\n(kJ/m³) Data de atualização
# 2              2,004             528,51919      42662,1051          13/03/2023
# 17           2,00144             528,22646      38798,0539          13/03/2023
# 18           2,00144             528,22646      38798,0539          13/03/2023
# 19           2,00144             528,22646      38798,0539          13/03/2023
# 20           2,00144             528,22646      38798,0539          13/03/2023
#
# [5 rows x 23 columns]

# %%
df['Óleo (bbl/dia)']
# Out:
# 2      24.589,0097
# 17      1.581,4644
# 18        558,4049
# 19      1.045,6631
# 20        982,3675
#           ...
# 343    10.217,2163
# 344    10.972,9944
# 345     3.896,5870
# 346     2.954,0391
# 347    11.995,2534
# Name: Óleo (bbl/dia), Length: 227, dtype: object

# %%
df['Óleo (bbl/dia)'].mean()
# Out:
# 6698.287354185022

# %%
df.describe()
# Out:
#        Óleo (bbl/dia)  Condensado (bbl/dia)  Petróleo (bbl/dia)  \
# count      227.000000                 227.0          227.000000
# mean      6698.287354                   0.0         6698.287354
# std      10021.302709                   0.0        10021.302709
# min          0.009500                   0.0            0.009500
# 25%        176.238550                   0.0          176.238550
# 50%       1534.334400                   0.0         1534.334400
# 75%       9559.862150                   0.0         9559.862150
# max      47718.134600                   0.0        47718.134600
#
#        Gás Natural (Mm³/dia)  Volume Gás Royalties (Mm³/dia)  Água (bbl/dia)  \
# count             227.000000                      227.000000      227.000000
# mean              269.486997                     2271.583119      297.487011
# std               501.302344                     3625.435833     1340.667647
# min                 0.000400                        0.000000        0.000000
# 25%                 7.967700                       71.148000        0.198100
# 50%                62.335200                      734.661000        5.174700
# 75%               301.025200                     3151.285500       31.867400
# max              3233.589700                    27864.142000    13260.475100
#
#        Tempo de Produção (hs por mês)    Grau API  Fração de Destilados  \
# count                      227.000000  227.000000                   0.0
# mean                       520.612335   28.638326                   NaN
# std                        179.533884    1.887496                   NaN
# min                          0.000000   22.200000                   NaN
# 25%                        433.500000   27.700000                   NaN
# 50%                        536.000000   28.700000                   NaN
# 75%                        677.000000   30.200000                   NaN
# max                        744.000000   30.200000                   NaN
#
#        % em Volumes  Densidade GLP Gás  Densidade GLP Líquido  PCS GP\n(kJ/m³)
# count    227.000000         227.000000             227.000000       227.000000
# mean      65.161780           2.017844             530.182206     35729.593112
# std        9.068674           0.020626               2.460202      4924.571040
# min       44.404000           1.998750             527.899640     22599.280500
# 25%       60.150000           2.001440             528.226460     35593.354600
# 50%       67.708000           2.004000             528.519190     38798.053900
# 75%       71.809000           2.044020             533.316010     38798.053900
# max       81.017000           2.048930             533.886990     42662.105100

# %%
producao_por_campo = df.groupby("Campo")["Óleo (bbl/dia)"].sum()
producao_por_campo
# Out:
# Campo
# ALBACORA             6578.6494
# ATAPU               45045.2612
# ATAPU_ECO           68993.7623
# AnC_MERO             7693.7327
# AnC_NORTE_ATAPU      1320.8938
# AnC_TUPI             3469.3319
# BARRACUDA           17970.5756
# BERBIGÃO            56242.6671
# BÚZIOS             151379.0773
# BÚZIOS_ECO         428161.9522
# CARATINGA           16588.2234
# ITAPU               26328.3465
# ITAPU_ECO           24589.0097
# JUBARTE             61524.3654
# LAPA                32920.5735
# MARLIM LESTE        12499.5077
# MARLIM SUL          12583.3878
# MERO               212127.1921
# OESTE DE ATAPU      23681.5415
# SUL DE BERBIGÃO     19812.3070
# SUL DE TUPI         46310.2203
# SURURU              73304.3987
# SÉPIA               46137.7641
# SÉPIA LESTE         20236.5083
# SÉPIA_ECO          101271.3949
# TAMBUATÁ             3740.5850
# Name: Óleo (bbl/dia), dtype: float64

# %%
producao_media_por_operador = df.groupby('Operador')['Petróleo (bbl/dia)'].mean()
producao_media_por_operador
# Out:
# Operador
# Petrobras           6670.810116
# TotalEnergies EP    8230.143375
# Name: Petróleo (bbl/dia), dtype: float64

# %%
import matplotlib.pyplot as plt

producao_por_campo.plot(kind='bar', figsize=(8,4))
plt.title('Produção de Óleo por Campo')
plt.xlabel('Campo')
plt.ylabel('Óleo (bbl/dia)')
plt.show()

# %%
# Comparar a produção de Óleo e Gás Natural por poço
plt.figure(figsize=(8,6))
plt.scatter(df['Óleo (bbl/dia)'], df['Gás Natural (Mm³/dia)'])
plt.title('Relação entre Produção de Óleo e Gás Natural')
plt.xlabel('Óleo (bbl/dia)')
plt.ylabel('Gás Natural (Mm³/dia)')
plt.show()

# %%
# Converter a coluna "Período" para o formato datetime
df['Período'] = pd.to_datetime(df['Período'], format='%Y/%m')

# Verificar as primeiras linhas para garantir que a conversão foi bem-sucedida
print(df[['Período']].head())
# Out:
#       Período
# 2  2023-01-01
# 17 2023-01-01
# 18 2023-01-01
# 19 2023-01-01
# 20 2023-01-01

# %%
# Produção total de Óleo por período
producao_ao_longo_do_tempo = df.groupby('Período')['Óleo (bbl/dia)'].sum()

# Exibir o resultado
print(producao_ao_longo_do_tempo)
# Out:
# Período
# 2023-01-01    1.520511e+06
# Name: Óleo (bbl/dia), dtype: float64

# %%
# Plotar a produção total de Óleo ao longo do tempo
producao_ao_longo_do_tempo.plot(figsize=(10,6))
plt.title('Produção Total de Óleo ao Longo do Tempo')
plt.xlabel('Período')
plt.ylabel('Óleo (bbl/dia)')
plt.xticks(rotation=45)
plt.show()

# %%
# Calcular a variação percentual mês a mês
producao_ao_longo_do_tempo_pct_change = producao_ao_longo_do_tempo.pct_change() * 100

# Exibir a variação percentual
print(producao_ao_longo_do_tempo_pct_change)

# Plotar a variação percentual ao longo do tempo
producao_ao_longo_do_tempo_pct_change.plot(figsize=(10,6))
plt.title('Variação Percentual da Produção de Óleo ao Longo do Tempo')
plt.xlabel('Período')
plt.ylabel('Variação Percentual (%)')
plt.xticks(rotation=45)
plt.show()
# Out:
# Período
# 2023-01-01   NaN
# Name: Óleo (bbl/dia), dtype: float64

# %%
# Verificar campos com produção muito alta ou muito baixa de Óleo
outliers_alta = df[df['Óleo (bbl/dia)'] > df['Óleo (bbl/dia)'].mean() + 3*df['Óleo (bbl/dia)'].std()]
outliers_baixa = df[df['Óleo (bbl/dia)'] < df['Óleo (bbl/dia)'].mean() - 3*df['Óleo (bbl/dia)'].std()]

print("Poços com produção muito alta de Óleo:\n", outliers_alta)
print("Poços com produção muito baixa de Óleo:\n", outliers_baixa)
# Out:
# Poços com produção muito alta de Óleo:
#               Estado   Bacia        Nome Poço  Unnamed: 3 Campo   Operador  \
# 148  Rio de Janeiro  Santos    7-MRO-10B-RJS  7MRO10BRJS  MERO  Petrobras
# 149  Rio de Janeiro  Santos  3-BRSA-1322-RJS     3RJS741  MERO  Petrobras
# 150  Rio de Janeiro  Santos     7-MRO-7A-RJS   7MRO7ARJS  MERO  Petrobras
# 151  Rio de Janeiro  Santos    7-MRO-6DB-RJS  7MRO6DBRJS  MERO  Petrobras
#
#        Período  Óleo (bbl/dia)  Condensado (bbl/dia)  Petróleo (bbl/dia)  ...  \
# 148 2023-01-01      46646.4524                   0.0          46646.4524  ...
# 149 2023-01-01      47718.1346                   0.0          47718.1346  ...
# 150 2023-01-01      43942.7246                   0.0          43942.7246  ...
# 151 2023-01-01      47443.1406                   0.0          47443.1406  ...
#
#      Unnamed: 38 Unnamed: 39 Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 148        0,001           0           0        0,045          0,6
# 149        0,001           0           0        0,045          0,6
# 150        0,001           0           0        0,045          0,6
# 151        0,001           0           0        0,045          0,6
#
#     Unnamed: 43 Densidade GLP Gás  Densidade GLP Líquido PCS GP\n(kJ/m³)  \
# 148      41,261           2.01679                530.063      22599.2805
# 149      41,261           2.01679                530.063      22599.2805
# 150      41,261           2.01679                530.063      22599.2805
# 151      41,261           2.01679                530.063      22599.2805
#
#      Data de atualização
# 148           13/03/2023
# 149           13/03/2023
# 150           13/03/2023
# 151           13/03/2023
#
# [4 rows x 46 columns]
# Poços com produção muito baixa de Óleo:
#  Empty DataFrame
# Columns: [Estado, Bacia, Nome Poço, Unnamed: 3, Campo, Operador, Período, Óleo (bbl/dia), Condensado (bbl/dia), Petróleo (bbl/dia), Gás Natural (Mm³/dia), Unnamed: 12, Unnamed: 13, Volume Gás Royalties (Mm³/dia), Água (bbl/dia), Instalação Destino, Tipo Instalação, Tempo de Produção (hs por mês), Corrente, Grau API, Fração de Destilados, Unnamed: 23, Unnamed: 24, Unnamed: 25, Unnamed: 26, Unnamed: 27, % em Volumes, Unnamed: 29, Unnamed: 30, Unnamed: 31, Unnamed: 32, Unnamed: 33, Unnamed: 34, Unnamed: 35, Unnamed: 36, Unnamed: 37, Unnamed: 38, Unnamed: 39, Unnamed: 40, Unnamed: 41, Unnamed: 42, Unnamed: 43, Densidade GLP Gás, Densidade GLP Líquido, PCS GP
# (kJ/m³), Data de atualização]
# Index: []
#
# [0 rows x 46 columns]
