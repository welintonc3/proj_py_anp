# %% [markdown]
# # Analise de produção por campo ANP

# %%
from jupyterthemes import jtplot
jtplot.style(theme = 'monokai')
import pandas as pd

# %%
# Let's load the new CSV file and repeat the process of inspecting its contents and performing the analysis.
file_path_new = '2023_01_producao_Presal.csv'

# Load the CSV file to inspect the data
df_new = pd.read_csv(file_path_new, sep=';', encoding='utf-8')

# Display the first few rows of the dataframe to understand its structure
df_new.head()
# Out:
#            Estado   Bacia        Nome Poço Unnamed: 3      Campo   Operador  \
# 0             NaN     NaN              ANP   Operador        NaN        NaN
# 1             NaN     NaN              NaN        NaN        NaN        NaN
# 2  Rio de Janeiro  Santos  1-BRSA-1116-RJS    1RJS704  ITAPU_ECO  Petrobras
# 3  Rio de Janeiro  Santos      7-LL-46-RJS   7LL46RJS       TUPI  Petrobras
# 4  Rio de Janeiro  Santos     7-LL-45D-RJS  7LL45DRJS       TUPI  Petrobras
#
#   Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  ...  \
# 0                NaN      NaN            NaN                  NaN  ...
# 1                NaN      NaN            NaN                  NaN  ...
# 2  48610012913201005  2023/01    24.589,0097               0,0000  ...
# 3    486100038862000  2023/01     9.268,5707               0,0000  ...
# 4    486100038862000  2023/01     2.229,7516               0,0000  ...
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42    Unnamed: 43  \
# ...

# %%
clear_col_df_new = df_new.loc[:,~df.columns.str.contains('^Unnamed')]
clear_col_df_new.head()
# Out:
#            Estado   Bacia        Nome Poço      Campo   Operador  \
# 0             NaN     NaN              ANP        NaN        NaN
# 1             NaN     NaN              NaN        NaN        NaN
# 2  Rio de Janeiro  Santos  1-BRSA-1116-RJS  ITAPU_ECO  Petrobras
# 3  Rio de Janeiro  Santos      7-LL-46-RJS       TUPI  Petrobras
# 4  Rio de Janeiro  Santos     7-LL-45D-RJS       TUPI  Petrobras
#
#   Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  \
# 0                NaN      NaN            NaN                  NaN
# 1                NaN      NaN            NaN                  NaN
# 2  48610012913201005  2023/01    24.589,0097               0,0000
# 3    486100038862000  2023/01     9.268,5707               0,0000
# 4    486100038862000  2023/01     2.229,7516               0,0000
#
#   Petróleo (bbl/dia)  ... Tempo de Produção (hs por mês) Período da Carga  \
# 0                NaN  ...                            NaN              NaN
# ...

# %%
clear_col_df_new.columns
# Out:
# Index(['Estado', 'Bacia', 'Nome Poço', 'Campo', 'Operador',
#        'Número do Contrato', 'Período', 'Óleo (bbl/dia)',
#        'Condensado (bbl/dia)', 'Petróleo (bbl/dia)', 'Gás Natural (Mm³/dia)',
#        'Volume Gás Royalties (Mm³/dia)', 'Água (bbl/dia)',
#        'Instalação Destino', 'Tipo Instalação',
#        'Tempo de Produção (hs por mês)', 'Período da Carga', 'Corrente',
#        'Grau API', 'Fração de Destilados', '% em Volumes', 'Densidade GLP Gás',
#        'Densidade GLP Líquido', 'PCS GP\n(kJ/m³)', 'Data de atualização'],
#       dtype='object')

# %%
# First, let's clean the dataset by removing any rows that do not have relevant production data (like the first few rows with NaN)
# Then we'll group by the 'Campo' column to calculate the total production of oil (Óleo) per field

# Clean the dataset by removing NaN rows in critical columns
df_clean = df.dropna(subset=['Campo', 'Óleo (bbl/dia)'])

# Convert the 'Óleo (bbl/dia)' column to a numerical format (removing commas and converting to float)
df_clean['Óleo (bbl/dia)'] = df_clean['Óleo (bbl/dia)'].str.replace('.', '').str.replace(',', '.').astype(float)

# Group the data by 'Campo' and sum the production of oil (Óleo)
production_by_field = df_clean.groupby('Campo')['Óleo (bbl/dia)'].sum().reset_index()

# Sort the data to see the fields with the highest production
production_by_field_sorted = production_by_field.sort_values(by='Óleo (bbl/dia)', ascending=False)

# Display the result
production_by_field_sorted.head(10)  # Display the top 10 fields by production
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_9436\4164093829.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Óleo (bbl/dia)'] = df_clean['Óleo (bbl/dia)'].str.replace('.', '').str.replace(',', '.').astype(float)
#          Campo  Óleo (bbl/dia)
# 32        TUPI     804538.7002
# 10  BÚZIOS_ECO     428161.9522
# 18        MERO     212127.1921
# 23    SAPINHOÁ     158170.5376
# 9       BÚZIOS     151379.0773
# 30   SÉPIA_ECO     101446.4210
# 27      SURURU      73304.3987
# 2    ATAPU_ECO      68993.7623
# 14     JUBARTE      61524.3654
# 8     BERBIGÃO      56242.6671

# %%
import matplotlib.pyplot as plt

# Plotting the top 10 fields by oil production
plt.figure(figsize=(10, 6))
plt.barh(production_by_field_sorted['Campo'].head(10), production_by_field_sorted['Óleo (bbl/dia)'].head(10), color='skyblue')
plt.xlabel('Produção de Óleo (bbl/dia)')
plt.ylabel('Campo')
plt.title('Top 10 Campos por Produção de Óleo')
plt.gca().invert_yaxis()  # Invert y-axis to show the highest value at the top
plt.show()
