# %% [markdown]
# # Analise de produção por campo BR ANP

# %% [markdown]
# #### Aqui vamos explorar um banco de dados da Petrobras, estatal brasileira de produção de petróleo, óleo e gás
# ##### Extrair informações sobre os campos de produção

# %%
from jupyterthemes import jtplot
jtplot.style(theme = 'monokai')
import pandas as pd
import numpy as np

# %%
# Recarregar o arquivo para redefinir 'clear_col_df_new' como DataFrame

novo_df = pd.read_csv('2023_01_producao_Presal.csv', sep=';', encoding='utf-8')

# %%
# Removendo colunas com "Unnamed"

df_anp_data = novo_df.loc[:,~ novo_df.columns.str.contains('^Unnamed')]
df_anp_data.head()
# Out:
#            Estado   Bacia        Nome Poço      Campo   Operador  \
# 0             NaN     NaN              ANP        NaN        NaN
# 1             NaN     NaN              NaN        NaN        NaN
# 2  Rio de Janeiro  Santos  1-BRSA-1116-RJS  ITAPU_ECO  Petrobras
# 3  Rio de Janeiro  Santos      7-LL-46-RJS       TUPI  Petrobras
# 4  Rio de Janeiro  Santos     7-LL-45D-RJS       TUPI  Petrobras
#
#   Número do Contrato  Período Óleo (bbl/dia) Condensado (bbl/dia)  \
# 0                NaN      NaN            NaN                  NaN
# 1                NaN      NaN            NaN                  NaN
# 2  48610012913201005  2023/01    24.589,0097               0,0000
# 3    486100038862000  2023/01     9.268,5707               0,0000
# 4    486100038862000  2023/01     2.229,7516               0,0000
#
#   Petróleo (bbl/dia)  ... Tempo de Produção (hs por mês) Período da Carga  \
# 0                NaN  ...                            NaN              NaN
# 1                NaN  ...                            NaN              NaN
# 2        24.589,0097  ...                            0.0          2022/12
# 3         9.268,5707  ...                          672.0          2022/02
# 4         2.229,7516  ...                          744.0          2022/02
#
#   Corrente Grau API Fração de Destilados  % em Volumes Densidade GLP Gás  \
# 0      NaN      NaN                Leves        Metano               NaN
# 1      NaN      NaN                Corte           NaN               NaN
# 2    ITAPU     29,3              < 270ºC        67,708             2,004
# 3     Tupi     30,7              < 270ºC           NaN               NaN
# 4     Tupi     30,7              < 270ºC           NaN               NaN
#
#   Densidade GLP Líquido PCS GP\n(kJ/m³) Data de atualização
# 0                   NaN             NaN                 NaN
# 1                   NaN             NaN                 NaN
# 2             528,51919      42662,1051          13/03/2023
# 3                   NaN             NaN          13/03/2023
# 4                   NaN             NaN          13/03/2023
#
# [5 rows x 25 columns]

# %%
df_anp_data.shape
# Out:
# (348, 25)

# %%
# Aplicar as conversões de tipo nas colunas desejadas
numero_colunas = [
    'Óleo (bbl/dia)', 'Condensado (bbl/dia)', 'Petróleo (bbl/dia)', 'Gás Natural (Mm³/dia)', 
    'Volume Gás Royalties (Mm³/dia)', 'Água (bbl/dia)', 'Grau API'
]

for col in numero_colunas:
    # Remover pontos de milhar e substituir vírgulas por pontos
    df_anp_data[col] = df_anp_data[col].str.replace('.', '', regex=False)
    df_anp_data[col] = df_anp_data[col].str.replace(',', '.', regex=False)
    # Converte para float
    df_anp_data[col] = pd.to_numeric(df_anp_data[col], errors='coerce')

# Verifique as informações para confirmar as conversões
df_anp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Estado                          346 non-null    object
#  1   Bacia                           346 non-null    object
#  2   Nome Poço                       347 non-null    object
#  3   Campo                           346 non-null    object
#  4   Operador                        346 non-null    object
#  5   Número do Contrato              346 non-null    object
#  6   Período                         346 non-null    object
#  7   Óleo (bbl/dia)                  346 non-null    float64
#  8   Condensado (bbl/dia)            346 non-null    float64
#  9   Petróleo (bbl/dia)              346 non-null    float64
#  10  Gás Natural (Mm³/dia)           346 non-null    float64
#  11  Volume Gás Royalties (Mm³/dia)  346 non-null    float64
#  12  Água (bbl/dia)                  346 non-null    float64
#  13  Instalação Destino              344 non-null    object
#  14  Tipo Instalação                 344 non-null    object
#  15  Tempo de Produção (hs por mês)  346 non-null    float64
#  16  Período da Carga                342 non-null    object
#  17  Corrente                        342 non-null    object
#  18  Grau API                        342 non-null    float64
#  19  Fração de Destilados            348 non-null    object
#  20  % em Volumes                    233 non-null    object
#  21  Densidade GLP Gás               232 non-null    object
#  22  Densidade GLP Líquido           232 non-null    object
#  23  PCS GP
# (kJ/m³)                  232 non-null    object
#  24  Data de atualização             346 non-null    object
# dtypes: float64(8), object(17)
# memory usage: 68.1+ KB
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\2163341258.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_data[col] = df_anp_data[col].str.replace('.', '', regex=False)
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\2163341258.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_data[col] = df_anp_data[col].str.replace(',', '.', regex=False)
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\2163341258.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_data[col] = pd.to_numeric(df_anp_data[col], errors='coerce')

# %%
# Lista das colunas convertidas para tipo numérico
df_anp_data.columns
# Out:
# Index(['Estado', 'Bacia', 'Nome Poço', 'Campo', 'Operador',
#        'Número do Contrato', 'Período', 'Óleo (bbl/dia)',
#        'Condensado (bbl/dia)', 'Petróleo (bbl/dia)', 'Gás Natural (Mm³/dia)',
#        'Volume Gás Royalties (Mm³/dia)', 'Água (bbl/dia)',
#        'Instalação Destino', 'Tipo Instalação',
#        'Tempo de Produção (hs por mês)', 'Período da Carga', 'Corrente',
#        'Grau API', 'Fração de Destilados', '% em Volumes', 'Densidade GLP Gás',
#        'Densidade GLP Líquido', 'PCS GP\n(kJ/m³)', 'Data de atualização'],
#       dtype='object')

# %%
# Obter os índices das colunas em numeric_columns
numero_idx = [df_anp_data.columns.get_loc(col) for col in numero_colunas]

# Exibir os índices
print(numero_idx)
# Out:
# [7, 8, 9, 10, 11, 12, 18]

# %%
# Selecionar todas as linhas das colunas com índices em selecao_linha_colunas
selecao_linha_colunas = df_anp_data.iloc[:, numero_idx]

# Exibir o DataFrame resultante com todas as linhas e colunas selecionadas
print(selecao_linha_colunas)
# Out:
#      Óleo (bbl/dia)  Condensado (bbl/dia)  Petróleo (bbl/dia)  \
# 0               NaN                   NaN                 NaN
# 1               NaN                   NaN                 NaN
# 2        24589.0097                   0.0          24589.0097
# 3         9268.5707                   0.0           9268.5707
# 4         2229.7516                   0.0           2229.7516
# ..              ...                   ...                 ...
# 343      10217.2163                   0.0          10217.2163
# 344      10972.9944                   0.0          10972.9944
# 345       3896.5870                   0.0           3896.5870
# 346       2954.0391                   0.0           2954.0391
# 347      11995.2534                   0.0          11995.2534
#
#      Gás Natural (Mm³/dia)  Volume Gás Royalties (Mm³/dia)  Água (bbl/dia)  \
# 0                      NaN                             NaN             NaN
# 1                      NaN                             NaN             NaN
# 2                 288.0496                        8897.091         15.4500
# 3                1112.1985                       20207.690        246.9645
# 4                 149.6987                        2719.897      11168.6152
# ..                     ...                             ...             ...
# 343               553.7107                        3649.903          0.0000
# 344               373.1134                        2459.457          4.9198
# 345               241.5630                        1592.314         17.0322
# 346               177.8065                        1172.049          1.7295
# 347               490.1517                        3230.941          0.0000
#
#      Grau API
# 0         NaN
# 1         NaN
# 2        29.3
# 3        30.7
# 4        30.7
# ..        ...
# 343      28.7
# 344      28.7
# 345      28.7
# 346      28.7
# 347      28.7
#
# [348 rows x 7 columns]

# %%
selecao_linha_colunas.isna()
# Out:
#      Óleo (bbl/dia)  Condensado (bbl/dia)  Petróleo (bbl/dia)  \
# 0              True                  True                True
# 1              True                  True                True
# 2             False                 False               False
# 3             False                 False               False
# 4             False                 False               False
# ..              ...                   ...                 ...
# 343           False                 False               False
# 344           False                 False               False
# 345           False                 False               False
# 346           False                 False               False
# 347           False                 False               False
#
#      Gás Natural (Mm³/dia)  Volume Gás Royalties (Mm³/dia)  Água (bbl/dia)  \
# 0                     True                            True            True
# 1                     True                            True            True
# 2                    False                           False           False
# 3                    False                           False           False
# 4                    False                           False           False
# ..                     ...                             ...             ...
# 343                  False                           False           False
# 344                  False                           False           False
# 345                  False                           False           False
# 346                  False                           False           False
# 347                  False                           False           False
#
#      Grau API
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# ..        ...
# 343     False
# 344     False
# 345     False
# 346     False
# 347     False
#
# [348 rows x 7 columns]

# %%
selecao_linha_colunas.isna().sum()
# Out:
# Óleo (bbl/dia)                    2
# Condensado (bbl/dia)              2
# Petróleo (bbl/dia)                2
# Gás Natural (Mm³/dia)             2
# Volume Gás Royalties (Mm³/dia)    2
# Água (bbl/dia)                    2
# Grau API                          6
# dtype: int64

# %%
selecao_linha_colunas.duplicated().sum()
# Out:
# 3

# %%
filtro_data_df_duplicada = selecao_linha_colunas.duplicated()

# %%
filtro_data_df_duplicada.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 348 entries, 0 to 347
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 348 non-null    bool
# dtypes: bool(1)
# memory usage: 480.0 bytes

# %%
df_anp_data["Óleo (bbl/dia)"]
# Out:
# 0             NaN
# 1             NaN
# 2      24589.0097
# 3       9268.5707
# 4       2229.7516
#           ...
# 343    10217.2163
# 344    10972.9944
# 345     3896.5870
# 346     2954.0391
# 347    11995.2534
# Name: Óleo (bbl/dia), Length: 348, dtype: float64

# %%
df_anp_data["Estado"].unique()
# Out:
# array([nan, 'Rio de Janeiro', 'São Paulo', 'Espírito Santo'], dtype=object)

# %%
df_anp_data[df_anp_data["Estado"].isnull()].head()
# Out:
#   Estado Bacia Nome Poço Campo Operador Número do Contrato Período  \
# 0    NaN   NaN       ANP   NaN      NaN                NaN     NaN
# 1    NaN   NaN       NaN   NaN      NaN                NaN     NaN
#
#    Óleo (bbl/dia)  Condensado (bbl/dia)  Petróleo (bbl/dia)  ...  \
# 0             NaN                   NaN                 NaN  ...
# 1             NaN                   NaN                 NaN  ...
#
#    Tempo de Produção (hs por mês)  Período da Carga  Corrente Grau API  \
# 0                             NaN               NaN       NaN      NaN
# 1                             NaN               NaN       NaN      NaN
#
#   Fração de Destilados  % em Volumes Densidade GLP Gás Densidade GLP Líquido  \
# 0                Leves        Metano               NaN                   NaN
# 1                Corte           NaN               NaN                   NaN
#
#    PCS GP\n(kJ/m³) Data de atualização
# 0              NaN                 NaN
# 1              NaN                 NaN
#
# [2 rows x 25 columns]

# %%
df_anp_data["Tempo de Produção (hs por mês)"]
# Out:
# 0        NaN
# 1        NaN
# 2        0.0
# 3      672.0
# 4      744.0
#        ...
# 343    529.0
# 344    537.0
# 345    345.0
# 346    537.0
# 347    531.0
# Name: Tempo de Produção (hs por mês), Length: 348, dtype: float64

# %%
# Preencher os valores Nan 
df_anp_data.fillna(0)
# Out:
#              Estado   Bacia        Nome Poço      Campo   Operador  \
# 0                 0       0              ANP          0          0
# 1                 0       0                0          0          0
# 2    Rio de Janeiro  Santos  1-BRSA-1116-RJS  ITAPU_ECO  Petrobras
# 3    Rio de Janeiro  Santos      7-LL-46-RJS       TUPI  Petrobras
# 4    Rio de Janeiro  Santos     7-LL-45D-RJS       TUPI  Petrobras
# ..              ...     ...              ...        ...        ...
# 343  Rio de Janeiro  Santos    7-BUZ-31D-RJS     BÚZIOS  Petrobras
# 344  Rio de Janeiro  Santos     7-BUZ-30-RJS     BÚZIOS  Petrobras
# 345  Rio de Janeiro  Santos    7-BUZ-29D-RJS     BÚZIOS  Petrobras
# 346  Rio de Janeiro  Santos   7-BUZ-36DA-RJS     BÚZIOS  Petrobras
# 347  Rio de Janeiro  Santos    7-BUZ-24D-RJS     BÚZIOS  Petrobras
#
#     Número do Contrato  Período  Óleo (bbl/dia)  Condensado (bbl/dia)  \
# 0                    0        0          0.0000                   0.0
# 1                    0        0          0.0000                   0.0
# 2    48610012913201005  2023/01      24589.0097                   0.0
# 3      486100038862000  2023/01       9268.5707                   0.0
# 4      486100038862000  2023/01       2229.7516                   0.0
# ..                 ...      ...             ...                   ...
# 343  48610012913201005  2023/01      10217.2163                   0.0
# 344  48610012913201005  2023/01      10972.9944                   0.0
# 345  48610012913201005  2023/01       3896.5870                   0.0
# 346  48610012913201005  2023/01       2954.0391                   0.0
# 347  48610012913201005  2023/01      11995.2534                   0.0
#
#      Petróleo (bbl/dia)  ...  Tempo de Produção (hs por mês)  \
# 0                0.0000  ...                             0.0
# 1                0.0000  ...                             0.0
# 2            24589.0097  ...                             0.0
# 3             9268.5707  ...                           672.0
# 4             2229.7516  ...                           744.0
# ..                  ...  ...                             ...
# 343          10217.2163  ...                           529.0
# 344          10972.9944  ...                           537.0
# 345           3896.5870  ...                           345.0
# 346           2954.0391  ...                           537.0
# 347          11995.2534  ...                           531.0
#
#      Período da Carga  Corrente Grau API Fração de Destilados  % em Volumes  \
# 0                   0         0      0.0                Leves        Metano
# 1                   0         0      0.0                Corte             0
# 2             2022/12     ITAPU     29.3              < 270ºC        67,708
# 3             2022/02      Tupi     30.7              < 270ºC             0
# 4             2022/02      Tupi     30.7              < 270ºC             0
# ..                ...       ...      ...                  ...           ...
# 343           2022/02    Búzios     28.7              < 270ºC         60,15
# 344           2022/02    Búzios     28.7              < 270ºC         60,15
# 345           2022/02    Búzios     28.7              < 270ºC         60,15
# 346           2022/02    Búzios     28.7              < 270ºC         60,15
# 347           2022/02    Búzios     28.7              < 270ºC         60,15
#
#     Densidade GLP Gás Densidade GLP Líquido  PCS GP\n(kJ/m³)  \
# 0                   0                     0                0
# 1                   0                     0                0
# 2               2,004             528,51919       42662,1051
# 3                   0                     0                0
# 4                   0                     0                0
# ..                ...                   ...              ...
# 343           2,04893             533,88699       35593,3546
# 344           2,04893             533,88699       35593,3546
# 345           2,04893             533,88699       35593,3546
# 346           2,04893             533,88699       35593,3546
# 347           2,04893             533,88699       35593,3546
#
#     Data de atualização
# 0                     0
# 1                     0
# 2            13/03/2023
# 3            13/03/2023
# 4            13/03/2023
# ..                  ...
# 343          13/03/2023
# 344          13/03/2023
# 345          13/03/2023
# 346          13/03/2023
# 347          13/03/2023
#
# [348 rows x 25 columns]

# %%
df_anp_data.isna().sum()
# Out:
# Estado                              2
# Bacia                               2
# Nome Poço                           1
# Campo                               2
# Operador                            2
# Número do Contrato                  2
# Período                             2
# Óleo (bbl/dia)                      2
# Condensado (bbl/dia)                2
# Petróleo (bbl/dia)                  2
# Gás Natural (Mm³/dia)               2
# Volume Gás Royalties (Mm³/dia)      2
# Água (bbl/dia)                      2
# Instalação Destino                  4
# Tipo Instalação                     4
# Tempo de Produção (hs por mês)      2
# Período da Carga                    6
# Corrente                            6
# Grau API                            6
# Fração de Destilados                0
# % em Volumes                      115
# Densidade GLP Gás                 116
# Densidade GLP Líquido             116
# PCS GP\n(kJ/m³)                   116
# Data de atualização                 2
# dtype: int64

# %%
df_anp_data["Tempo de Produção (hs por mês)"].unique()
# Out:
# array([ nan,   0., 672., 744., 657., 677., 444., 548., 188., 680., 678.,
#        674., 529., 535., 685., 423., 426., 652., 663., 644., 491., 645.,
#        511., 650., 639., 665.,  45., 287., 682., 542., 231., 728., 323.,
#        356., 317., 348., 447., 429., 136., 653., 646., 524., 477., 500.,
#        731., 742., 676., 661.,  75., 438., 708., 158., 715., 709., 718.,
#        592., 706., 312., 505., 700., 689., 473., 688., 662., 364., 385.,
#        371.,   1.,  53., 449., 442., 360., 730., 738., 698., 743., 716.,
#        540., 428., 512., 536., 527., 532., 701., 699., 679., 690., 539.,
#        533., 537., 345., 531.])

# %%
df_anp_data["Tempo de Produção (hs por mês)"].describe()
# Out:
# count    346.000000
# mean     538.471098
# std      194.040592
# min        0.000000
# 25%      447.000000
# 50%      548.000000
# 75%      685.000000
# max      744.000000
# Name: Tempo de Produção (hs por mês), dtype: float64

# %%
df_anp_data.value_counts
# Out:
# <bound method DataFrame.value_counts of              Estado   Bacia        Nome Poço      Campo   Operador  \
# 0               NaN     NaN              ANP        NaN        NaN
# 1               NaN     NaN              NaN        NaN        NaN
# 2    Rio de Janeiro  Santos  1-BRSA-1116-RJS  ITAPU_ECO  Petrobras
# 3    Rio de Janeiro  Santos      7-LL-46-RJS       TUPI  Petrobras
# 4    Rio de Janeiro  Santos     7-LL-45D-RJS       TUPI  Petrobras
# ..              ...     ...              ...        ...        ...
# 343  Rio de Janeiro  Santos    7-BUZ-31D-RJS     BÚZIOS  Petrobras
# 344  Rio de Janeiro  Santos     7-BUZ-30-RJS     BÚZIOS  Petrobras
# 345  Rio de Janeiro  Santos    7-BUZ-29D-RJS     BÚZIOS  Petrobras
# 346  Rio de Janeiro  Santos   7-BUZ-36DA-RJS     BÚZIOS  Petrobras
# 347  Rio de Janeiro  Santos    7-BUZ-24D-RJS     BÚZIOS  Petrobras
#
#     Número do Contrato  Período  Óleo (bbl/dia)  Condensado (bbl/dia)  \
# 0                  NaN      NaN             NaN                   NaN
# 1                  NaN      NaN             NaN                   NaN
# 2    48610012913201005  2023/01      24589.0097                   0.0
# 3      486100038862000  2023/01       9268.5707                   0.0
# 4      486100038862000  2023/01       2229.7516                   0.0
# ..                 ...      ...             ...                   ...
# 343  48610012913201005  2023/01      10217.2163                   0.0
# 344  48610012913201005  2023/01      10972.9944                   0.0
# 345  48610012913201005  2023/01       3896.5870                   0.0
# 346  48610012913201005  2023/01       2954.0391                   0.0
# 347  48610012913201005  2023/01      11995.2534                   0.0
#
#      Petróleo (bbl/dia)  ...  Tempo de Produção (hs por mês)  \
# 0                   NaN  ...                             NaN
# 1                   NaN  ...                             NaN
# 2            24589.0097  ...                             0.0
# 3             9268.5707  ...                           672.0
# 4             2229.7516  ...                           744.0
# ..                  ...  ...                             ...
# 343          10217.2163  ...                           529.0
# 344          10972.9944  ...                           537.0
# 345           3896.5870  ...                           345.0
# 346           2954.0391  ...                           537.0
# 347          11995.2534  ...                           531.0
#
#      Período da Carga  Corrente Grau API Fração de Destilados  % em Volumes  \
# 0                 NaN       NaN      NaN                Leves        Metano
# 1                 NaN       NaN      NaN                Corte           NaN
# 2             2022/12     ITAPU     29.3              < 270ºC        67,708
# 3             2022/02      Tupi     30.7              < 270ºC           NaN
# 4             2022/02      Tupi     30.7              < 270ºC           NaN
# ..                ...       ...      ...                  ...           ...
# 343           2022/02    Búzios     28.7              < 270ºC         60,15
# 344           2022/02    Búzios     28.7              < 270ºC         60,15
# 345           2022/02    Búzios     28.7              < 270ºC         60,15
# 346           2022/02    Búzios     28.7              < 270ºC         60,15
# 347           2022/02    Búzios     28.7              < 270ºC         60,15
#
#     Densidade GLP Gás Densidade GLP Líquido  PCS GP\n(kJ/m³)  \
# 0                 NaN                   NaN              NaN
# 1                 NaN                   NaN              NaN
# 2               2,004             528,51919       42662,1051
# 3                 NaN                   NaN              NaN
# 4                 NaN                   NaN              NaN
# ..                ...                   ...              ...
# 343           2,04893             533,88699       35593,3546
# 344           2,04893             533,88699       35593,3546
# 345           2,04893             533,88699       35593,3546
# 346           2,04893             533,88699       35593,3546
# 347           2,04893             533,88699       35593,3546
#
#     Data de atualização
# 0                   NaN
# 1                   NaN
# 2            13/03/2023
# 3            13/03/2023
# 4            13/03/2023
# ..                  ...
# 343          13/03/2023
# 344          13/03/2023
# 345          13/03/2023
# 346          13/03/2023
# 347          13/03/2023
#
# [348 rows x 25 columns]>

# %%
df_anp_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 343    False
# 344    False
# 345    False
# 346    False
# 347    False
# Length: 348, dtype: bool

# %%
# obtendo a informação de quantas amostras diferentes
df_anp_data[df_anp_data.isna().any(axis=1)]
# Out:
#              Estado   Bacia         Nome Poço     Campo   Operador  \
# 0               NaN     NaN               ANP       NaN        NaN
# 1               NaN     NaN               NaN       NaN        NaN
# 3    Rio de Janeiro  Santos       7-LL-46-RJS      TUPI  Petrobras
# 4    Rio de Janeiro  Santos      7-LL-45D-RJS      TUPI  Petrobras
# 5    Rio de Janeiro  Santos      7-LL-73D-RJS      TUPI  Petrobras
# ..              ...     ...               ...       ...        ...
# 308       São Paulo  Santos      7-SPH-4D-SPS  SAPINHOÁ  Petrobras
# 309       São Paulo  Santos       7-SPH-3-SPS  SAPINHOÁ  Petrobras
# 310       São Paulo  Santos      7-SPH-2D-SPS  SAPINHOÁ  Petrobras
# 311       São Paulo  Santos    9-BRSA-928-SPS  SAPINHOÁ  Petrobras
# 312  Rio de Janeiro  Santos  4-BRSA-1386D-RJS     SÉPIA  Petrobras
#
#     Número do Contrato  Período  Óleo (bbl/dia)  Condensado (bbl/dia)  \
# 0                  NaN      NaN             NaN                   NaN
# 1                  NaN      NaN             NaN                   NaN
# 3      486100038862000  2023/01       9268.5707                   0.0
# 4      486100038862000  2023/01       2229.7516                   0.0
# 5      486100038862000  2023/01       1981.8641                   0.0
# ..                 ...      ...             ...                   ...
# 308    486100038842000  2023/01      14295.8289                   0.0
# 309    486100038842000  2023/01      18879.0400                   0.0
# 310    486100038842000  2023/01      12317.7440                   0.0
# 311    486100038842000  2023/01          0.0899                   0.0
# 312  48610226559202149  2023/01         79.7426                   0.0
#
#      Petróleo (bbl/dia)  ...  Tempo de Produção (hs por mês)  \
# 0                   NaN  ...                             NaN
# 1                   NaN  ...                             NaN
# 3             9268.5707  ...                           672.0
# 4             2229.7516  ...                           744.0
# 5             1981.8641  ...                           744.0
# ..                  ...  ...                             ...
# 308          14295.8289  ...                           662.0
# 309          18879.0400  ...                           685.0
# 310          12317.7440  ...                           689.0
# 311              0.0899  ...                             1.0
# 312             79.7426  ...                            53.0
#
#      Período da Carga  Corrente Grau API Fração de Destilados  % em Volumes  \
# 0                 NaN       NaN      NaN                Leves        Metano
# 1                 NaN       NaN      NaN                Corte           NaN
# 3             2022/02      Tupi     30.7              < 270ºC           NaN
# 4             2022/02      Tupi     30.7              < 270ºC           NaN
# 5             2022/02      Tupi     30.7              < 270ºC           NaN
# ..                ...       ...      ...                  ...           ...
# 308           2022/02  Sapinhoá     30.1              < 270ºC           NaN
# 309           2022/02  Sapinhoá     30.1              < 270ºC           NaN
# 310           2022/02  Sapinhoá     30.1              < 270ºC           NaN
# 311           2022/02  Sapinhoá     30.1              < 270ºC           NaN
# 312           2022/05     SEPIA     27.4              < 270ºC          56,4
#
#     Densidade GLP Gás Densidade GLP Líquido  PCS GP\n(kJ/m³)  \
# 0                 NaN                   NaN              NaN
# 1                 NaN                   NaN              NaN
# 3                 NaN                   NaN              NaN
# 4                 NaN                   NaN              NaN
# 5                 NaN                   NaN              NaN
# ..                ...                   ...              ...
# 308               NaN                   NaN              NaN
# 309               NaN                   NaN              NaN
# 310               NaN                   NaN              NaN
# 311               NaN                   NaN              NaN
# 312           2,00036              528,0935       30198,2427
#
#     Data de atualização
# 0                   NaN
# 1                   NaN
# 3            13/03/2023
# 4            13/03/2023
# 5            13/03/2023
# ..                  ...
# 308          13/03/2023
# 309          13/03/2023
# 310          13/03/2023
# 311          13/03/2023
# 312          13/03/2023
#
# [121 rows x 25 columns]

# %%
filtro = df_anp_data["Tempo de Produção (hs por mês)"].isna()

# %%
comp_anp_data = df_anp_data[["Tempo de Produção (hs por mês)","Petróleo (bbl/dia)","Óleo (bbl/dia)","Gás Natural (Mm³/dia)"]]
comp_anp_data
# Out:
#      Tempo de Produção (hs por mês)  Petróleo (bbl/dia)  Óleo (bbl/dia)  \
# 2                               0.0          24589.0097      24589.0097
# 3                             672.0           9268.5707       9268.5707
# 4                             744.0           2229.7516       2229.7516
# 5                             744.0           1981.8641       1981.8641
# 6                             657.0           7980.3577       7980.3577
# ..                              ...                 ...             ...
# 343                           529.0          10217.2163      10217.2163
# 344                           537.0          10972.9944      10972.9944
# 345                           345.0           3896.5870       3896.5870
# 346                           537.0           2954.0391       2954.0391
# 347                           531.0          11995.2534      11995.2534
#
#      Gás Natural (Mm³/dia)
# 2                 288.0496
# 3                1112.1985
# 4                 149.6987
# 5                 116.4249
# 6                1206.1087
# ..                     ...
# 343               553.7107
# 344               373.1134
# 345               241.5630
# 346               177.8065
# 347               490.1517
#
# [346 rows x 4 columns]

# %%
df_anp_data[filtro][["Petróleo (bbl/dia)","Óleo (bbl/dia)","Gás Natural (Mm³/dia)"]]
# Out:
#    Petróleo (bbl/dia)  Óleo (bbl/dia)  Gás Natural (Mm³/dia)
# 0                 NaN             NaN                    NaN
# 1                 NaN             NaN                    NaN

# %%
df_anp_data['Tempo de Produção (hs por mês)'].fillna(
    np.ceil(
        df_anp_data['Petróleo (bbl/dia)'] / df_anp_data['Óleo (bbl/dia)'] / df_anp_data['Gás Natural (Mm³/dia)']
    ),inplace=True
)
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\3815514713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_data['Tempo de Produção (hs por mês)'].fillna(

# %%
df_anp_data[filtro][["Petróleo (bbl/dia)","Óleo (bbl/dia)","Gás Natural (Mm³/dia)"]]
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\2983346793.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_anp_data[filtro][["Petróleo (bbl/dia)","Óleo (bbl/dia)","Gás Natural (Mm³/dia)"]]
# Empty DataFrame
# Columns: [Petróleo (bbl/dia), Óleo (bbl/dia), Gás Natural (Mm³/dia)]
# Index: []

# %%
df_anp_data["Petróleo (bbl/dia)"].value_counts()
# Out:
# Petróleo (bbl/dia)
# 0.0000        3
# 24589.0097    1
# 7026.8262     1
# 29805.4926    1
# 1.0999        1
#              ..
# 3566.0307     1
# 24074.5361    1
# 21365.7817    1
# 19812.3070    1
# 11995.2534    1
# Name: count, Length: 344, dtype: int64

# %%
coluna_anp_dropa = comp_anp_data[["Tempo de Produção (hs por mês)","Petróleo (bbl/dia)","Óleo (bbl/dia)","Gás Natural (Mm³/dia)"]]

# %%
coluna_anp_dropa = ["Tempo de Produção (hs por mês)", "Petróleo (bbl/dia)", "Óleo (bbl/dia)", "Gás Natural (Mm³/dia)"]
df_anp_data.dropna(subset=coluna_anp_dropa, inplace=True)
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_8856\2947489098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_data.dropna(subset=coluna_anp_dropa, inplace=True)

# %%
coluna_anp_dropa.value_counts()
# Out:
# Tempo de Produção (hs por mês)  Petróleo (bbl/dia)  Óleo (bbl/dia)  Gás Natural (Mm³/dia)
# 0.0                             0.0000              0.0000          0.0000                   3
# 677.0                           1284.4922           1284.4922       44.6277                  1
# 678.0                           604.3170            604.3170        21.1945                  1
#                                 93.4037             93.4037         8.4632                   1
#                                 45.2724             45.2724         1.5878                   1
#                                                                                             ..
# 511.0                           106.3615            106.3615        4.7144                   1
# 505.0                           19308.2532          19308.2532      702.3676                 1
#                                 435.6888            435.6888        15.8489                  1
#                                 253.4333            253.4333        9.2190                   1
# 744.0                           30938.0577          30938.0577      1497.9248                1
# Name: count, Length: 344, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Remover valores nulos antes de plotar
coluna_anp_dropa = coluna_anp_dropa.dropna(subset=["Tempo de Produção (hs por mês)", "Petróleo (bbl/dia)", "Óleo (bbl/dia)", "Gás Natural (Mm³/dia)"])

# 1. Gráfico de dispersão entre Petróleo e Gás Natural
plt.figure(figsize=(10, 6))
plt.scatter(coluna_anp_dropa["Petróleo (bbl/dia)"], coluna_anp_dropa["Gás Natural (Mm³/dia)"], alpha=0.6)
plt.title("Relação entre Produção de Petróleo e Gás Natural")
plt.xlabel("Petróleo (bbl/dia)")
plt.ylabel("Gás Natural (Mm³/dia)")
plt.show()

# 2. Gráfico de linha para o Tempo de Produção
plt.figure(figsize=(10, 6))
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Petróleo (bbl/dia)"], label="Petróleo (bbl/dia)")
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Óleo (bbl/dia)"], label="Óleo (bbl/dia)")
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Gás Natural (Mm³/dia)"], label="Gás Natural (Mm³/dia)")
plt.title("Produção ao longo do Tempo")
plt.xlabel("Tempo de Produção (hs por mês)")
plt.ylabel("Produção")
plt.legend()
plt.show()

# 3. Gráfico de pares para todas as variáveis
sns.pairplot(coluna_anp_dropa[["Petróleo (bbl/dia)", "Óleo (bbl/dia)", "Gás Natural (Mm³/dia)"]])
plt.show()

# %%
# Ordenando o DataFrame pela coluna de Tempo de Produção
coluna_anp_dropa = coluna_anp_dropa.sort_values(by="Tempo de Produção (hs por mês)")

# Replotar o gráfico de linha
plt.figure(figsize=(10, 6))
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Petróleo (bbl/dia)"], label="Petróleo (bbl/dia)")
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Óleo (bbl/dia)"], label="Óleo (bbl/dia)")
plt.plot(coluna_anp_dropa["Tempo de Produção (hs por mês)"], coluna_anp_dropa["Gás Natural (Mm³/dia)"], label="Gás Natural (Mm³/dia)")
plt.title("Produção ao longo do Tempo de Produção")
plt.xlabel("Tempo de Produção (hs por mês)")
plt.ylabel("Produção")
plt.legend()
plt.show()
